# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# # Rashika Suresh --- DataScience and Business Analytics Intern

# %% [markdown]
# ## Task 6 >> Prediction using Decision Tree Algorithm

# %% [markdown]
# ### From the 'Iris Dataset', create a decision tree classifier and visualize it graphically. The purpose is to predict the right class when new data is given to this classifier

# %% [markdown]
# ### Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Importing the datasets

# %%
iris_df=pd.read_csv('Iris.csv')
iris_df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
iris_df.drop(['Id'],axis=1,inplace=True)
print("Data loaded successfully")
# Out:
# Data loaded successfully

# %% [markdown]
# ### Exploring the data

# %%
iris_df.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa
# 6            4.6           3.4            1.4           0.3  Iris-setosa
# 7            5.0           3.4            1.5           0.2  Iris-setosa
# 8            4.4           2.9            1.4           0.2  Iris-setosa
# 9            4.9           3.1            1.5           0.1  Iris-setosa

# %%
iris_df.tail(10)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 140            6.7           3.1            5.6           2.4  Iris-virginica
# 141            6.9           3.1            5.1           2.3  Iris-virginica
# 142            5.8           2.7            5.1           1.9  Iris-virginica
# 143            6.8           3.2            5.9           2.3  Iris-virginica
# 144            6.7           3.3            5.7           2.5  Iris-virginica
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris_df.groupby('Species').describe()
# Out:
#                 SepalLengthCm                                              \
#                         count   mean       std  min    25%  50%  75%  max
# Species
# Iris-setosa              50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor          50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica           50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 SepalWidthCm         ... PetalLengthCm      PetalWidthCm  \
#                        count   mean  ...           75%  max        count
# Species                              ...
# Iris-setosa             50.0  3.418  ...         1.575  1.9         50.0
# Iris-versicolor         50.0  2.770  ...         4.600  5.1         50.0
# Iris-virginica          50.0  2.974  ...         5.875  6.9         50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# Species
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# ...

# %% [markdown]
# ### Visualizing using boxplot

# %%
features = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
for feature in features:
    sns.boxplot(x='Species',y=feature,data = iris_df, palette='icefire')
    plt.show()

# %% [markdown]
# ### Corelation matrix

# %%
plt.figure(figsize=(7,4))
sns.heatmap(iris_df.corr(), annot=True, cmap='YlGnBu')

# %% [markdown]
# ### Checking for null values

# %%
iris_df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris_df.shape
# Out:
# (150, 5)

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# ### Scatterplot

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',data=iris_df,hue='Species')

# %%
sns.scatterplot(x='PetalLengthCm',y='PetalWidthCm',data=iris_df,hue='Species')

# %% [markdown]
# ### Pairplot

# %%
sns.pairplot(iris_df, hue='Species')

# %% [markdown]
# ### Jointplot

# %%
sns.jointplot(x='SepalLengthCm',y='SepalWidthCm', data=iris_df)

# %%
sns.jointplot(x='PetalLengthCm',y='PetalWidthCm', data=iris_df)

# %% [markdown]
# ### Countplot

# %%
sns.countplot(x='PetalWidthCm' , data=iris_df)

# %%
sns.countplot(x='SepalWidthCm' , data=iris_df)

# %%
iris_df.hist(figsize = (20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B897719F98>,
# ...
#       dtype=object)

# %% [markdown]
# ### Subplot of all columns

# %%
# It plots subplots of all columns based on selection and divisionof region 
plt.figure(figsize=(18,9))
plt.subplot(2,2,1)
sns.distplot(iris_df['SepalLengthCm'].values,bins=30, kde=True, rug=True )
plt.title('Sepal Length')
plt.subplot(2,2,2)
sns.distplot(iris_df['SepalWidthCm'].values,bins=30, kde=True, rug=True )
plt.title('Sepal Width')
plt.subplot(2,2,3)
sns.distplot(iris_df['PetalLengthCm'].values,bins=30, kde=True, rug=True )
plt.title('Petal Length')
plt.subplot(2,2,4)
sns.distplot(iris_df['PetalWidthCm'].values,bins=30, kde=True, rug=True )
plt.title('Petal Width')
# Out:
# Text(0.5, 1.0, 'Petal Width')

# %% [markdown]
# ### Separating dependent and independent variables

# %%
x=iris_df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y=iris_df['Species']

# %%
from sklearn.preprocessing import LabelEncoder
lbe= LabelEncoder()
y=lbe.fit_transform(y)

# %%
# Creating training and test data using train_test_split method
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.2,random_state=42)
print("Shape of feature training data :",xtrain.shape)
print("Shape of target training data :",ytrain.shape)
print("Shape of feature test data :",xtest.shape)
print("Shape of target test data :",ytest.shape)
# Out:
# Shape of feature training data : (120, 4)
# Shape of target training data : (120,)
# Shape of feature test data : (30, 4)
# Shape of target test data : (30,)

# %% [markdown]
# ### Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtree= DecisionTreeClassifier()
dtree.fit(xtrain,ytrain)# Fitting the model on training data
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
print("Decision tree created")
# Out:
# Decision tree created

# %%
ypred=dtree.predict(xtest)  # Prediction on the testing data.
ypred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %% [markdown]
# ### Accuracy, Confusion matrix and Classification Report of the model

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score
acc=cross_val_score(estimator=dtree,X=xtrain,y=ytrain,cv=10)
print('Mean:{:.2f}% '.format(acc.mean()*100))
print('Std: {:.2f}% '.format(acc.std()*100))
# Out:
# Mean:91.66%
# Std: 9.87%

# %% [markdown]
# ### Classification Report

# %%
print("Classification Report is:\n")
print(classification_report(ytest,ypred))
# Out:
# Classification Report is:
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %% [markdown]
# ### Accuracy of training data

# %%
predict = dtree.predict(xtrain)
print("Accuracy of training data : ",accuracy_score(predict,ytrain)*100,"%")
print("Confusin matrix of training data :'\n' ",confusion_matrix(predict,ytrain))
sns.heatmap(confusion_matrix(predict,ytrain),annot = True,cmap = 'BuGn')
# Out:
# Accuracy of training data :  100.0 %
# Confusin matrix of training data :'
# '  [[40  0  0]
#  [ 0 41  0]
#  [ 0  0 39]]

# %% [markdown]
# ### Accuracy for testing data

# %%
predict = dtree.predict(xtest)
print("Accuracy of testing data : ",accuracy_score(predict,ytest)*100,"%")
print("Confusin matrix of testing data :\n ",confusion_matrix(predict,ytest))
sns.heatmap(confusion_matrix(predict,ytest),annot = True,cmap = 'BuGn')
# Out:
# Accuracy of testing data :  100.0 %
# Confusin matrix of testing data :
#   [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %% [markdown]
# ### Plotting tree

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(35,25))
tree_img = plot_tree(dtree.fit(x,y),feature_names=iris_df.columns,class_names=iris_df['Species'].unique().tolist(),filled=True,precision=4,node_ids = True, label="all",proportion=True,rounded=True,fontsize=25)
plt.show()

# %% [markdown]
# #### Accuracy of decision tree classifier is 100% and deviation is 8.97%
