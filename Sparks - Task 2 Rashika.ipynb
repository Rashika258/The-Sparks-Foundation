# %% [markdown]
# # The Sparks Foundation

# %% [markdown]
# # Rashika Suresh --- DataScience and Business Analytics Intern

# %% [markdown]
# ## Task 2 >> Prediction using Unsupervised ML

# %% [markdown]
# ## From the given ‘Iris’ dataset, predict the optimum number of clusters and represent it visually.

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
from sklearn.cluster import KMeans

# %% [markdown]
# ### Loading the datasets

# %%
iris = datasets.load_iris()

# %%
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
print("Data loaded successfully")
# Out:
# Data loaded successfully

# %%
iris_df.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1

# %%
iris_df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8

# %% [markdown]
# ### Data Exploration

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
#Checking if dataset has null values

iris_df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
#Checking for duplicated values

iris_df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# #### Dataset has one duplicated value

# %%
#Shape
iris_df.shape
# Out:
# (150, 4)

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
#Computing the corelation matrix

iris_df.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %% [markdown]
# ## Defining target and predictors

# %%
X = iris.data[:, :2] #taking the first two features

y = iris.target

# %% [markdown]
# #### Visualising data using scatterplot

# %%
plt.scatter(X[: , 0], X[: , 1], c = y, cmap = 'gist_rainbow')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %%
plt.scatter(X[: , 0], X[: , 1], c = y, cmap = 'gist_earth')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
# Out:
# Text(0, 0.5, 'Sepal Width')

# %% [markdown]
# ### Instantiating and fitting K-means cluster model using four clusters and random state of 17

# %%
km = KMeans(n_clusters = 4, n_jobs = 4, random_state = 17)

km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=4, precompute_distances='auto',
#        random_state=17, tol=0.0001, verbose=0)

# %% [markdown]
# ### Identifying the center points of the data

# %%
centers = km.cluster_centers_

print(centers)
# Out:
# [[5.90980392 2.73529412]
#  [6.85348837 3.1       ]
#  [4.76666667 2.89166667]
#  [5.1875     3.6375    ]]

# %% [markdown]
# ### Comparing original data with clustered data

# %%
new_labels = km.labels_

# %%
fig, axes = plt.subplots(1, 2, figsize = (16 , 8))

axes[0].scatter(X[: , 0], X[: , 1], c = y, cmap = 'gist_rainbow', edgecolor = 'k', s = 150)

axes[0].set_xlabel('Sepal length', fontsize = 18)

axes[0].set_ylabel('Sepal width', fontsize = 18)

axes[0].tick_params(direction = 'in', length = 10, width = 5, colors = 'k', labelsize = 20)

axes[0].set_title('Actual', fontsize = 18)

axes[1].scatter(X[: , 0], X[: , 1], c = new_labels, cmap = 'jet', edgecolor = 'k', s = 150)

axes[1].set_xlabel('Sepal length', fontsize = 18)

axes[1].set_ylabel('Sepal width', fontsize = 18)

axes[1].tick_params(direction = 'in', length = 10, width = 5, colors = 'k', labelsize = 20)

axes[1].set_title('Predicted', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Predicted')

# %% [markdown]
# ## K-means Clustering

# %% [markdown]
# ### Importing the libraries

# %%
# The required libraries are imported already

# %% [markdown]
# ### Loading the iris dataset

# %%
# The iris data set has been loaded already and also explored

# %%
iris_df.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1

# %% [markdown]
# ### Finding the optimum number of clusters

# %% [markdown]
# #### Using elbow method, to find the optimum number of clusters. It plots the explained variation as a number of clusters and picking the elbow of the curve as the number of curves to use.

# %%
#Finding the optimal number of clusters

value_of_range = range(1,10)
w= []
for k in value_of_range:
    km = KMeans(n_clusters=k)
    km.fit(x)
    w.append(km.inertia_)
    
w
# Out:
# [681.3706,
#  152.34795176035792,
#  78.85144142614601,
#  57.228473214285714,
#  46.472230158730156,
#  41.81520454545455,
#  34.42777741702742,
#  30.06459307359308,
#  27.895494645705178]

# %% [markdown]
# #### Elbow plot

# %%
plt.plot(k_rng, sse)
plt.xlabel('K')
plt.ylabel('Sum of Squared Error (SSE)')
# Out:
# Text(0, 0.5, 'Sum of Squared Error (SSE)')

# %% [markdown]
# ### Training model and visualising the result

# %%
km = KMeans(n_clusters = 3)
y_pred = km.fit_predict(x)

# %%
#Plotting the clusters
plt.figure(figsize=(8,8))
plt.scatter(x[y_pred == 0, 0], x[y_pred == 0, 1], s = 50, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_pred == 1, 0], x[y_pred == 1, 1], s = 50, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_pred == 2, 0], x[y_pred == 2, 1], s = 50, c = 'green', label = 'Iris-virginica')

#Plotting centroids of the clusters
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:,1], s = 50, c = 'yellow', label = 'Centroids')

plt.legend()
